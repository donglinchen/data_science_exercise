# %% [markdown]
# ## Logistic regression
#
# While linear regression model is used for predict continunous numbers, Logistic regression model is used to seperate an event from one class from anoter based on probability.
#
# A sigmoid function is used to transform a linear function into a binary classification function where it outputs a value between 0 and 1 to indicate the probability of binary classification. Multinomial logistic regression can be used to handel situations where the outcome can have three or more possible types.
#
# This time we will use machine learning to create a model that predicts which passengers survived the Titanic shipwreck. The data set is availble from Kaggle at https://www.kaggle.com/c/titanic/data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Gather Data

# %%
df = pd.read_csv('kaggle_data/titanic/train.csv')
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a9daa_row0_col0,#T_a9daa_row1_col1,#T_a9daa_row2_col2,#T_a9daa_row3_col3,#T_a9daa_row4_col4,#T_a9daa_row5_col5,#T_a9daa_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a9daa_row0_col1{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_a9daa_row0_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_a9daa_row0_col3{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_a9daa_row0_col4,#T_a9daa_row3_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_a9daa_row0_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_a9daa_row0_col6{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_a9daa_row1_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_a9daa_row1_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_a9daa_row1_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_a9daa_row1_col4{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_a9daa_row1_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_a9daa_row1_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_a9daa_row2_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_a9daa_row2_col1,#T_a9daa_row2_col3,#T_a9daa_row2_col6,#T_a9daa_row3_col4,#T_a9daa_row3_col5,#T_a9daa_row4_col0,#T_a9daa_row6_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_a9daa_row2_col4{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_a9daa_row2_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_a9daa_row3_col0{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_a9daa_row3_col2{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_a9daa_row3_col6{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_a9daa_row4_col1{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_a9daa_row4_col2{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_a9daa_row4_col3{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_a9daa_row4_col5{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_a9daa_row4_col6{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_a9daa_row5_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_a9daa_row5_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_a9daa_row5_col2{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_a9daa_row5_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_a9daa_row5_col4{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_a9daa_row5_col6{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_a9daa_row6_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_a9daa_row6_col1{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_a9daa_row6_col3{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_a9daa_row6_col4{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_a9daa_row6_col5{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }</style><table id="T_a9daa_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PassengerId</th>        <th class="col_heading level0 col1" >Survived</th>        <th class="col_heading level0 col2" >Pclass</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >SibSp</th>        <th class="col_heading level0 col5" >Parch</th>        <th class="col_heading level0 col6" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9daa_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#                         <td id="T_a9daa_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a9daa_row0_col1" class="data row0 col1" >-0.005007</td>
#                         <td id="T_a9daa_row0_col2" class="data row0 col2" >-0.035144</td>
#                         <td id="T_a9daa_row0_col3" class="data row0 col3" >0.036847</td>
#                         <td id="T_a9daa_row0_col4" class="data row0 col4" >-0.057527</td>
#                         <td id="T_a9daa_row0_col5" class="data row0 col5" >-0.001652</td>
#                         <td id="T_a9daa_row0_col6" class="data row0 col6" >0.012658</td>
#             </tr>
#             <tr>
#                         <th id="T_a9daa_level0_row1" class="row_heading level0 row1" >Survived</th>
#                         <td id="T_a9daa_row1_col0" class="data row1 col0" >-0.005007</td>
#                         <td id="T_a9daa_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_a9daa_row1_col2" class="data row1 col2" >-0.338481</td>
#                         <td id="T_a9daa_row1_col3" class="data row1 col3" >-0.077221</td>
#                         <td id="T_a9daa_row1_col4" class="data row1 col4" >-0.035322</td>
#                         <td id="T_a9daa_row1_col5" class="data row1 col5" >0.081629</td>
#                         <td id="T_a9daa_row1_col6" class="data row1 col6" >0.257307</td>
#             </tr>
#             <tr>
#                         <th id="T_a9daa_level0_row2" class="row_heading level0 row2" >Pclass</th>
#                         <td id="T_a9daa_row2_col0" class="data row2 col0" >-0.035144</td>
#                         <td id="T_a9daa_row2_col1" class="data row2 col1" >-0.338481</td>
#                         <td id="T_a9daa_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_a9daa_row2_col3" class="data row2 col3" >-0.369226</td>
#                         <td id="T_a9daa_row2_col4" class="data row2 col4" >0.083081</td>
#                         <td id="T_a9daa_row2_col5" class="data row2 col5" >0.018443</td>
#                         <td id="T_a9daa_row2_col6" class="data row2 col6" >-0.549500</td>
#             </tr>
#             <tr>
#                         <th id="T_a9daa_level0_row3" class="row_heading level0 row3" >Age</th>
#                         <td id="T_a9daa_row3_col0" class="data row3 col0" >0.036847</td>
#                         <td id="T_a9daa_row3_col1" class="data row3 col1" >-0.077221</td>
#                         <td id="T_a9daa_row3_col2" class="data row3 col2" >-0.369226</td>
#                         <td id="T_a9daa_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_a9daa_row3_col4" class="data row3 col4" >-0.308247</td>
#                         <td id="T_a9daa_row3_col5" class="data row3 col5" >-0.189119</td>
#                         <td id="T_a9daa_row3_col6" class="data row3 col6" >0.096067</td>
#             </tr>
#             <tr>
#                         <th id="T_a9daa_level0_row4" class="row_heading level0 row4" >SibSp</th>
#                         <td id="T_a9daa_row4_col0" class="data row4 col0" >-0.057527</td>
#                         <td id="T_a9daa_row4_col1" class="data row4 col1" >-0.035322</td>
#                         <td id="T_a9daa_row4_col2" class="data row4 col2" >0.083081</td>
#                         <td id="T_a9daa_row4_col3" class="data row4 col3" >-0.308247</td>
#                         <td id="T_a9daa_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_a9daa_row4_col5" class="data row4 col5" >0.414838</td>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isnull().any(axis=0)[df.isnull().any(axis=0)]
# Out:
# Age         True
# Cabin       True
# Embarked    True
# dtype: bool

# %%
fig, ax =plt.subplots(1,2, sharey=True)
fig.set_size_inches(12,6)
ax[0].scatter(x='Pclass', y='Age', data=df, alpha=0.2)
ax[1].scatter(x='SibSp', y='Age', data=df, alpha=0.2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['Pclass', 'SibSp', 'Parch', 'Fare']], df['Survived'], test_size=0.25, random_state=42)

# %% [markdown]
# ## Defind a Logistic regression model
# using default hyper paramters https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(X_test[['Pclass', 'SibSp', 'Parch', 'Fare']])

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[112  22]
#  [ 42  47]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       134
#            1       0.68      0.53      0.59        89
#
#     accuracy                           0.71       223
#    macro avg       0.70      0.68      0.69       223
# weighted avg       0.71      0.71      0.70       223

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       134
#            1       0.68      0.53      0.59        89
#
#     accuracy                           0.71       223
#    macro avg       0.70      0.68      0.69       223
# weighted avg       0.71      0.71      0.70       223
